# %% [markdown]
# # Zero-shot prediction of BRCA1 variant effects with Evo 2
# Deploy this tutorial on brev.dev:
# [![ Click here to deploy.](https://brev-assets.s3.us-west-1.amazonaws.com/nv-lb-dark.svg)](https://console.brev.dev/launchable/deploy?launchableID=env-2uGqxNLgVdl752F2qcTFwHHn4Rj)
#
# *Note - this notebook is a reproduction of The Arc Institute’s same-titled notebook [here](https://github.com/ArcInstitute/evo2/blob/main/notebooks/brca1/brca1_zero_shot_vep.ipynb), using the BioNeMo 2 implementation of Evo2.*
#
# Evo2 is a foundation AI model trained on 9.3 trillion DNA base pairs, predicting variant effects without prior tast-specific training.
#
# Without being explicitly trained on BRCA1 variants, we show Evo 2's ability to generalize across all life forms.
#
# The human *BRCA1* gene encodes for a protein that repairs damaged DNA ([Moynahan et al., 1999](https://www.cell.com/molecular-cell/fulltext/S1097-2765%2800%2980202-6)). Certain variants of this gene have been associated with an increased risk of breast and ovarian cancers ([Miki et al., 1994](https://www.science.org/doi/10.1126/science.7545954?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub%20%200pubmed)). Using Evo 2, we can predict whether a particular single nucleotide variant (SNV) of the *BRCA1* gene is likely to be harmful to the protein's function, and thus potentially increase the risk of cancer for the patient with the genetic variant.

# %%
# check if using the container's env
import sys
print(sys.executable)
# Out:
# /usr/bin/python

# %%
# check how many gpus
import torch
print(torch.cuda.device_count())
# Out:
# 8

# %%
# %%capture
# !pip install biopython openpyxl
import os


# Runs a subset of the model layers to test that the notebook runs in CI, but the output will be incorrect.
FAST_CI_MODE: bool = os.environ.get("FAST_CI_MODE", False)

# %%
import glob
import gzip
import json
import math
import os
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
from Bio import SeqIO
from sklearn.metrics import auc, roc_auc_score, roc_curve

from bionemo.core.utils.subprocess_utils import run_subprocess_safely

# %% [markdown]
# We start by loading a dataset from [Findlay et al. (2018)](https://www.nature.com/articles/s41586-018-0461-z), which contains experimentally measured function scores of 3,893 *BRCA1* SNVs. These function scores reflect the extent by which the genetic variant has disrupted the protein's function, with lower scores indicating greater disruption. In this dataset, the SNVs are classified into three categories based on their function scores: `LOF` (loss-of-function), `INT` (intermediate), and `FUNC` (functional). We start by reading in this dataset.
#
# To keep the notebook streamlined, we've abstracted much of the preprocessing logic into accompanying scripts located in `brca1_utils`. This notebook can also be viewed [here](https://docs.nvidia.com/bionemo-framework/latest/main/examples/bionemo-evo2/zeroshot_brca1/).

# %%
def download_data(data_dir="brca1", commit_hash="3819474bee6c24938016614411f1fa025e542bbe"):
    """Download required data files if they don't exist locally.

    Parameters:
    -----------
    data_dir : str
        Directory to store downloaded files
    commit_hash : str
        GitHub commit hash for data version
    """
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    excel_path = os.path.join(data_dir, "41586_2018_461_MOESM3_ESM.xlsx")
    genome_path = os.path.join(data_dir, "GRCh37.p13_chr17.fna.gz")

    if not os.path.exists(excel_path):
        os.system(
            f"wget https://github.com/ArcInstitute/evo2/raw/{commit_hash}/notebooks/brca1/41586_2018_461_MOESM3_ESM.xlsx -O {excel_path}"
        )

    if not os.path.exists(genome_path):
        os.system(
            f"wget https://github.com/ArcInstitute/evo2/raw/{commit_hash}/notebooks/brca1/GRCh37.p13_chr17.fna.gz -O {genome_path}"
        )

    return excel_path, genome_path


def load_genome_sequence(genome_path):
    """Load genome sequence from FASTA file.

    Parameters:
    -----------
    genome_path : str
        Path to the genome FASTA file

    Returns:
    --------
    str
        Genome sequence string
    """
    with gzip.open(genome_path, "rt") as handle:
        for record in SeqIO.parse(handle, "fasta"):
            return str(record.seq)

    raise ValueError("Failed to parse genome sequence")


def load_brca1_data(excel_path):
    """Load and preprocess BRCA1 data from Excel file.

    Parameters:
    -----------
    excel_path : str
        Path to the Excel file

    Returns:
    --------
    pandas.DataFrame
        Processed BRCA1 dataframe
    """
    # Load the dataframe
    brca1_df = pd.read_excel(excel_path, header=2)

    # Select and rename columns
    brca1_df = brca1_df[
        [
            "chromosome",
            "position (hg19)",
            "reference",
            "alt",
            "function.score.mean",
            "func.class",
        ]
    ]

    brca1_df.rename(
        columns={
            "chromosome": "chrom",
            "position (hg19)": "pos",
            "reference": "ref",
            "alt": "alt",
            "function.score.mean": "score",
            "func.class": "class",
        },
        inplace=True,
    )

    # Convert to two-class system
    brca1_df["class"] = brca1_df["class"].replace(["FUNC", "INT"], "FUNC/INT")

    return brca1_df

# %%
# %%capture

# Configuration parameters
DATA_DIR = "brca1"
SAMPLE_CONFIG = {"sample_frac": 0.05, "balanced": True, "disable": False, "random_state": 42}

# 1. Download the necessary data files if not present
excel_path, genome_path = download_data(DATA_DIR)
seq_chr17 = load_genome_sequence(genome_path)

# 2. Load and preprocess BRCA1 data
brca1_df = load_brca1_data(excel_path)
# Out:
# --2025-11-05 00:20:51--  https://github.com/ArcInstitute/evo2/raw/3819474bee6c24938016614411f1fa025e542bbe/notebooks/brca1/41586_2018_461_MOESM3_ESM.xlsx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ArcInstitute/evo2/3819474bee6c24938016614411f1fa025e542bbe/notebooks/brca1/41586_2018_461_MOESM3_ESM.xlsx [following]
# --2025-11-05 00:20:52--  https://raw.githubusercontent.com/ArcInstitute/evo2/3819474bee6c24938016614411f1fa025e542bbe/notebooks/brca1/41586_2018_461_MOESM3_ESM.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2268761 (2.2M) [application/octet-stream]
# Saving to: ‘brca1/41586_2018_461_MOESM3_ESM.xlsx’
#
#      0K .......... .......... .......... .......... ..........  2% 75.8M 0s
#     50K .......... .......... .......... .......... ..........  4% 55.5M 0s
#    100K .......... .......... .......... .......... ..........  6% 63.6M 0s
#    150K .......... .......... .......... .......... ..........  9%  122M 0s
#    200K .......... .......... .......... .......... .......... 11% 1.13G 0s
#    250K .......... .......... .......... .......... .......... 13% 84.3M 0s
#    300K .......... .......... .......... .......... .......... 15% 1.16G 0s
#    350K .......... .......... .......... .......... .......... 18% 78.9M 0s
#    400K .......... .......... .......... .......... .......... 20% 1.18G 0s
#    450K .......... .......... .......... .......... .......... 22% 1.29G 0s
#    500K .......... .......... .......... .......... .......... 24% 1.19G 0s
#    550K .......... .......... .......... .......... .......... 27%  158M 0s
# We build a function to parse the reference and variant sequences of a 8,192-bp window around the genomic position of each SNV, using the reference sequence of human chromosome 17 where *BRCA1* is located.

# %% [markdown]
# To make things run faster, we'll just look at a balanced sample of our data. If you want to run on the full dataset, set `disable_sample=True`

# %%
def sample_data(df, sample_frac=1.0, balanced=True, disable=False, random_state=42):
    """Sample dataframe, optionally with balanced classes.

    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe
    sample_frac : float
        Fraction of data to sample
    balanced : bool
        Whether to balance classes
    disable : bool
        Whether to disable sampling
    random_state : int
        Random seed for reproducibility

    Returns:
    --------
    pandas.DataFrame
        Sampled dataframe
    """
    if disable:
        return df

    if balanced:
        # Get the number of rows in the dataframe
        num_rows_minor_class = math.ceil(len(df[df["class"] == "LOF"]) * sample_frac)
        return (
            pd.concat(
                [
                    df[df["class"] == "LOF"].sample(n=num_rows_minor_class, random_state=random_state),
                    df[df["class"] == "FUNC/INT"].sample(n=num_rows_minor_class, random_state=random_state),
                ]
            )
            .sample(frac=1.0, random_state=random_state)
            .reset_index(drop=True)
        )
    else:
        # Calculate the number of rows to sample
        return df.sample(frac=sample_frac, random_state=random_state).reset_index(drop=True)

# %%
OUTPUT_DIR = "brca1_fasta_files"

brca1_df = sample_data(
    brca1_df,
    sample_frac=SAMPLE_CONFIG["sample_frac"],
    balanced=SAMPLE_CONFIG["balanced"],
    disable=SAMPLE_CONFIG["disable"],
    random_state=SAMPLE_CONFIG["random_state"],
)

brca1_df.head(5)
# Out:
#    chrom       pos ref alt     score     class
# 0     17  41199726   T   C  0.159762  FUNC/INT
# 1     17  41209074   T   A -2.065569       LOF
# 2     17  41256913   A   C -0.847753  FUNC/INT
# 3     17  41219631   T   A -2.053739       LOF
# 4     17  41215965   G   A -1.671525       LOF

# %% [markdown]
# Next, we'll write these to local `.fasta` files so we can use them for prediction below.

# %%
def parse_sequences(pos, ref, alt, seq_chr17, window_size=8192):
    """Parse reference and variant sequences from the reference genome sequence.

    Parameters:
    -----------
    pos : int
        Position (1-indexed)
    ref : str
        Reference base
    alt : str
        Alternate base
    seq_chr17 : str
        Full chromosome 17 sequence
    window_size : int
        Size of the sequence window to extract

    Returns:
    --------
    tuple
        (reference_sequence, variant_sequence)
    """
    p = pos - 1  # Convert to 0-indexed position
    full_seq = seq_chr17

    ref_seq_start = max(0, p - window_size // 2)
    ref_seq_end = min(len(full_seq), p + window_size // 2)
    ref_seq = seq_chr17[ref_seq_start:ref_seq_end]
    snv_pos_in_ref = min(window_size // 2, p)
    var_seq = ref_seq[:snv_pos_in_ref] + alt + ref_seq[snv_pos_in_ref + 1 :]

    # Sanity checks
    assert len(var_seq) == len(ref_seq)
    assert ref_seq[snv_pos_in_ref] == ref
    assert var_seq[snv_pos_in_ref] == alt

    return ref_seq, var_seq


def generate_fasta_files(df, seq_chr17, output_dir="brca1_fasta_files", window_size=8192):
    """Generate FASTA files for reference and variant sequences.

    Parameters:
    -----------
    df : pandas.DataFrame
        Dataframe with variant information
    seq_chr17 : str
        Chromosome 17 sequence
    output_dir : str
        Output directory for FASTA files
    window_size : int
        Size of sequence window

    Returns:
    --------
    pandas.DataFrame
        Dataframe with added columns for FASTA names
    """
    # Create output directory
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # Paths for output files
    ref_fasta_path = output_dir / "brca1_reference_sequences.fasta"
    var_fasta_path = output_dir / "brca1_variant_sequences.fasta"

    # Track unique sequences
    ref_sequences = set()
    var_sequences = set()
    ref_seq_to_name = {}

    # Store unique sequences with metadata for writing
    ref_entries = []
    var_entries = []
    ref_names = []
    var_names = []

    # Collect unique reference and variant sequences
    for idx, row in df.iterrows():
        ref_seq, var_seq = parse_sequences(row["pos"], row["ref"], row["alt"], seq_chr17, window_size)

        # Add to sets to ensure uniqueness
        if ref_seq not in ref_sequences:
            ref_sequences.add(ref_seq)
            ref_name = f"BRCA1_ref_pos_{row['pos']}_{row['ref']}_class_{row['class']}"

            ref_entries.append(f">{ref_name}\n{ref_seq}\n")
            ref_names.append(ref_name)
            ref_seq_to_name[ref_seq] = ref_name
        else:
            ref_name = ref_seq_to_name[ref_seq]
            ref_names.append(ref_name)

        if var_seq not in var_sequences:
            var_sequences.add(var_seq)
            var_name = f"BRCA1_var_pos_{row['pos']}_{row['ref']}to{row['alt']}_class_{row['class']}"

            var_entries.append(f">{var_name}\n{var_seq}\n")
            var_names.append(var_name)
        else:
            assert False, "Duplicate variant sequence"

    # Write unique sequences to FASTA files
    with open(ref_fasta_path, "w") as f:
        f.writelines(ref_entries)

    with open(var_fasta_path, "w") as f:
        f.writelines(var_entries)

    # Add FASTA names to dataframe
    df_with_names = df.copy()
    df_with_names["ref_fasta_name"] = ref_names
    df_with_names["var_fasta_name"] = var_names

    print(f"Total unique reference sequences: {len(ref_sequences)}")
    print(f"Total unique variant sequences: {len(var_sequences)}")

    return df_with_names

# %%
brca1_df = generate_fasta_files(brca1_df, seq_chr17, output_dir=OUTPUT_DIR)
# Out:
# Total unique reference sequences: 79
# Total unique variant sequences: 84

# %% [markdown]
# ### Load Evo 2 Checkpoints

# %% [markdown]
# Then, we load Evo 2 1B model, loading the Evo 2 weights from hugging face.
#
# *Note - for better performance, load the 7b model by setting `MODEL_SIZE="7b"` which also works well GPUs that do not support FP8.*

# %%
# %%capture
# MODEL_SIZE = "1b"  # also try 7b if you have a GPU with more than 32GB of memory

# # Define checkpoint path
# if MODEL_SIZE == "1b":
#     from bionemo.core.data.load import load

#     #  This line will download the checkpoint from NGC to your $HOME/.cache/bionemo directory and return the path.
#     #  To do the same from the command line, use `CHECKPOINT_PATH=$(download_bionemo_data evo2/1b-8k-bf16:1.0)`
#     checkpoint_path = load("evo2/1b-8k-bf16:1.0")
# else:
#     checkpoint_path = Path(f"nemo2_evo2_{MODEL_SIZE}_8k")

#     # Check if the directory does not exist or is empty
#     if not checkpoint_path.exists() or not any(checkpoint_path.iterdir()):
#         !evo2_convert_to_nemo2 --model-path hf://arcinstitute/savanna_evo2_{MODEL_SIZE}_base --model-size {MODEL_SIZE} --output-dir nemo2_evo2_{MODEL_SIZE}_8k
#     else:
#         print("Checkpoint directory is not empty. Skipping command.")

# %% [markdown]
# # 7b-1m

# %%
# # MODEL_SIZE = "7b"
# MODEL_SIZE = "7b_arc_longcontext"

# %%
# import logging
# logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# from bionemo.core.data.load import load
# checkpoint_path = load("evo2/7b-1m:1.0")
# Out:
# Downloading data from 'nvidia/clara/evo2-7b-1m-nemo2:1.0' to file '/root/.cache/bionemo/448cf1f09204c079f9be3e6a46d6349de563fc1713ae5c38c376cfb274647f94-nemo2_evo2_7b_1m.tar.gz'.
# 2025-11-04 21:54:16,707 - ngcbase.api.configuration - DEBUG - Loading config file: /root/.ngc/config
# 2025-11-04 21:54:16,707 - ngcbase.api.configuration - DEBUG - Loading meta_data file: /root/.ngc/meta_data
# 2025-11-04 21:54:16,708 - ngcbase.api.configuration - INFO - Validating configuration...
# 2025-11-04 21:54:16,708 - ngcbase.api.configuration - INFO - Successfully validated configuration.
# 2025-11-04 21:54:16,708 - ngcbase.api.connection - DEBUG - Requesting URL (GET): https://api.ngc.nvidia.com/v2/models/nvidia/clara/evo2-7b-1m-nemo2/versions/1.0
#     payload: None
#     params: None
# 2025-11-04 21:54:16,708 - ngcbase.api.utils - DEBUG - Headers:
# 2025-11-04 21:54:16,709 - ngcbase.api.utils - DEBUG - {'Content-Type': 'application/json', 'User-Agent': 'ngcsdk/3.64.3  linux-x86_64'}
# 2025-11-04 21:54:17,493 - ngcbase.api.connection - DEBUG - Response status: 200 - Reason: OK
# 2025-11-04 21:54:17,493 - ngcbase.api.connection - DEBUG - Time taken to process URL: https://api.ngc.nvidia.com/v2/models/nvidia/clara/evo2-7b-1m-nemo2/versions/1.0: 0.783681s
# 2025-11-04 21:54:17,494 - ngcbase.api.connection - DEBUG - Response is: {"modelVersion":{"totalSizeInBytes":10321831672,"policy":[],"status":"UPLOAD_COMPLETE","description":"","isSigned":false,"versionId":"1.0","createdByUser":"nvssa-prd-BR31we0_Tkhp_fvtm3i9fhQ2gz1GRAj7nOcxvVsRYe4","createdDate":"2025-03-05T00:07:02.156Z","totalFileCount":1,"updatedDate":"2025-03-05T00:07:15.370Z","storageVersion":"V1"},"model":{"orgName":"nvidia","labels":["NSPECT-WOD2-77AS"],"shortDescription":"Evo2 pretrained model weights for the 7b parameter model with 1m context, in nemo2 format.","isReadOnly":true,"publicDatasetUsed":{},"teamName":"clara","application":"OTHER","latestVersionSizeInBytes":10321831672,"isPublic":true,"hasSignedVersion":false,"latestVersionIdStr":"1.0","canGuestDownload":true,"precision":"OTHER","framework":"PyTorch","createdDate":"2025-03-05T00:07:01.825Z","name":"evo2-7b-1m-nemo2","publisher":"NVIDIA","displayName":"Evo2 7b parameter model with 1m context","modelFormat":"nemo2","updatedDate":"2025-03-05T00:07:15.375Z","isPlaygroundEnabled":false,"hasPlayground":false,"policyLabels":[]},"requestStatus":{"statusCode":"SUCCESS","requestId":"c147bd6b-a144-4cbc-a1ab-ac0c3679e5cf"}}
# 2025-11-04 21:54:17,494 - ngcbase.api.connection - DEBUG - Requesting URL (GET): https://api.ngc.nvidia.com/v2/models/nvidia/clara/evo2-7b-1m-nemo2/versions/1.0/files?page-size=1000
#     payload: None
#     params: None
# 2025-11-04 21:54:17,494 - ngcbase.api.utils - DEBUG - Headers:
# 2025-11-04 21:54:17,494 - ngcbase.api.utils - DEBUG - {'Content-Type': 'application/json', 'User-Agent': 'ngcsdk/3.64.3  linux-x86_64'}
# 2025-11-04 21:54:17,769 - ngcbase.api.connection - DEBUG - Response status: 200 - Reason: OK
# 2025-11-04 21:54:17,769 - ngcbase.api.connection - DEBUG - Time taken to process URL: https://api.ngc.nvidia.com/v2/models/nvidia/clara/evo2-7b-1m-nemo2/versions/1.0/files?page-size=1000: 0.273579s
# 2025-11-04 21:54:17,769 - ngcbase.api.connection - DEBUG - Response is: {"modelVersion":{"totalSizeInBytes":10321831672,"policy":[],"status":"UPLOAD_COMPLETE","description":"","isSigned":false,"versionId":"1.0","createdByUser":"nvssa-prd-BR31we0_Tkhp_fvtm3i9fhQ2gz1GRAj7nOcxvVsRYe4","createdDate":"2025-03-05T00:07:02.156Z","totalFileCount":1,"updatedDate":"2025-03-05T00:07:15.370Z","storageVersion":"V1"},"model":{"orgName":"nvidia","teamName":"clara","name":"evo2-7b-1m-nemo2"},"modelFiles":[{"sizeInBytes":10321831672,"path":"nemo2_evo2_7b_1m.tar.gz","sha256_base64":"RIzx8JIEwHn5vj5qRtY0neVj/BcTrlw4w3bPsnRkf5Q=","createdDate":"2025-03-05T00:07:15.360Z"}],"requestStatus":{"statusCode":"SUCCESS","requestId":"a07fecc2-3a60-439c-ba37-3e7c3fd73ba0"},"paginationInfo":{"totalPages":1,"index":0,"totalResults":1,"size":1000}}
# 2025-11-04 21:54:17,769 - registry.api.models - DEBUG - Downloading 1 files for model 'evo2-7b-1m-nemo2' version '1.0'
# 2025-11-04 21:54:17,770 - ngcbase.transfer.async_download - DEBUG - Preparing to download 1 files...
# 2025-11-04 21:54:17,772 - ngcbase.api.utils - DEBUG - Headers:
# 2025-11-04 21:54:17,772 - ngcbase.api.utils - DEBUG - {'Content-Type': 'application/json', 'User-Agent': 'ngcsdk/3.64.3  linux-x86_64'}
# 2025-11-04 21:54:17,773 - ngcbase.transfer.async_download - DEBUG - UUID for metric: cfb37584-b9c8-11f0-b32f-b90141e1df76
# 2025-11-04 21:54:18,426 - ngcbase.transfer.async_download - DEBUG - File direct URL response for file 'nemo2_evo2_7b_1m.tar.gz': 200
# 2025-11-04 21:54:18,527 - aiohttp.client - DEBUG - Error while closing connector: ClientConnectionError('Connection lost: SSL shutdown timed out')
# 2025-11-04 21:54:18,527 - ngcbase.transfer.async_download - DEBUG - File direct URL for file 'nemo2_evo2_7b_1m.tar.gz': https://xfiles.ngc.nvidia.com/org/nvidia/team/clara/models/evo2-7b-1m-nemo2/versions/1.0/files/nemo2_evo2_7b_1m.tar.gz?ssec-algo=AES256&versionId=BVtygJUo9yJAoJZJA_G50TALni8gEApR&ssec-key=SI9jopF3w8UImUYXuWG2nm2dNE9JJAOwkzUTUUAmjt3d5yS8UpV9LzRhQ031%2FWuvDmya4bVRUxEJID%2FRV6oT0JGx0b9GGH6i%2BtzKWr%2Bgvtnf4NUXBjtr91oNuaQBFUbtd0aygPgkk2apVh3dp2WmSPuLvSglNnnmSJXv6deh27JCWzN%2FWXmMczDs%2Bwhs4q9awPd%2F8E8SgJWtT9yA6eH9Z8t6Dm2nGkPBq%2BHRK%2FlBWiHng0hFDvbC8VaFKfUFCDnHnuxsTfeFShek4X7DZS59iNqD5jyF0LCJ7scZMeaBpC3WTWgnkYAy0x4KHuzlyKtHk11ZtYrQcQM6hK73OMvImwL5gxyP4MFNjkZLaoro3kUo5FbN23BfDAynz0dIdqfI%2FAsLb1sGkSRrD3Ne%2FMdbAM0%2FC7S7RkdScJs1XMQFnZG%2FS4qqUK48E77td%2BULh6wmcxyuXs1J2ExCjr3cPGB5XMEwjoARNF%2FPJaTc0Y0pvOGTn1xrDqIL377fXYZIubhe&kid=bXJrLWU3OGM1M2FhZjE4YzRiNmJiNjlkYmRhZjcxNjA3YWEw&ssec-enabled=true&Expires=1762379658&Signature=xzeGMvo0McQhQQGZ7iH~CZdsGEAM9hcH~Cm8P5BqgMP1MkiCY3-ygsMx5D3B~3rPx8s3SRkignB-WRlBp0nXTkh1~jRHrNLqhmrII0My~WN2S5E12MohMsHPHmI-3d568tvp-k0~cCnfc9025KNo2nGhtEYZ3eNaChPDrFxy6WURSkf8nrAPVW1q6Fgn0ur3p4BJqqhZiiDru6Klf4lm~FBn5iBW68EjvXpK24wbhu~IKoAUiyP1MC3QbjSDDyl4Op4RcbqbwCM3fKEFQoKv4vtN4PBKP97G~kXKfBZNcTsShf92XSQH9AG3NirCH5jcIkRn~LzWwhqfrMpcjWs7mw__&Key-Pair-Id=KCX06E8E9L60W
# 2025-11-04 21:54:18,538 - ngcbase.transfer.async_download - DEBUG -
# Timeout for file 'nemo2_evo2_7b_1m.tar.gz': 2h 44m 3s
# 2025-11-04 21:54:19,675 - ngcbase.transfer.async_download - DEBUG - File direct GET response for file 'nemo2_evo2_7b_1m.tar.gz': 200
# 2025-11-04 21:54:19,675 - ngcbase.transfer.async_download - DEBUG - response is 200
# 2025-11-04 21:57:35,753 - ngcbase.transfer.async_download - DEBUG - Finished writing 10321831672/10321831672 bytes to file '/root/.cache/bionemo/tmp0djy4al5/evo2-7b-1m-nemo2_v1.0/nemo2_evo2_7b_1m.tar.gz'
# 2025-11-04 21:57:35,754 - ngcbase.transfer.async_download - DEBUG - Finished file 'nemo2_evo2_7b_1m.tar.gz':  200
# {
#     "download_end": "2025-11-04 21:57:35",
#     "download_start": "2025-11-04 21:54:17",
#     "download_time": "3m 18s",
#     "files_downloaded": 1,
#     "local_path": "/root/.cache/bionemo/tmp0djy4al5/evo2-7b-1m-nemo2_v1.0",
#     "size_downloaded": "9.61 GB",
#     "status": "COMPLETED"
# }
# Untarring contents of '/root/.cache/bionemo/448cf1f09204c079f9be3e6a46d6349de563fc1713ae5c38c376cfb274647f94-nemo2_evo2_7b_1m.tar.gz' to '/root/.cache/bionemo/448cf1f09204c079f9be3e6a46d6349de563fc1713ae5c38c376cfb274647f94-nemo2_evo2_7b_1m.tar.gz.untar'

# %% [markdown]
# # 40b_1M

# %%
MODEL_SIZE = "40b_arc_longcontext"

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

from bionemo.core.data.load import load
checkpoint_path = load("evo2/40b-1m-fp8-bf16:1.0")
# Out:
# Using cached path='/root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar' from checked=PosixPath('/root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.checked')

# %% [markdown]
# ### Score Sequences

# %% [markdown]
# Next, we score the likelihoods of the reference and variant sequences of each SNV.

# %%
def check_fp8_support():
    """Check if FP8 is supported on the current GPU.

    FP8 requires compute capability 8.9+ (Ada Lovelace/Hopper architecture or newer).
    """
    if not torch.cuda.is_available():
        return False, "CUDA not available"

    device_props = torch.cuda.get_device_properties(0)
    compute_capability = f"{device_props.major}.{device_props.minor}"
    device_name = device_props.name

    # FP8 is supported on compute capability 8.9+ (Ada Lovelace/Hopper architecture)
    is_supported = (device_props.major > 8) or (device_props.major == 8 and device_props.minor >= 9)

    return is_supported, f"Device: {device_name}, Compute Capability: {compute_capability}"

# %%
# Define output directories for prediction results
output_dir = Path("brca1_fasta_files")
output_dir.mkdir(parents=True, exist_ok=True)

# Save reference and variant sequences to FASTA
ref_fasta_path = output_dir / "brca1_reference_sequences.fasta"
var_fasta_path = output_dir / "brca1_variant_sequences.fasta"

predict_ref_dir = output_dir / "reference_predictions"
predict_var_dir = output_dir / "variant_predictions"
predict_ref_dir.mkdir(parents=True, exist_ok=True)
predict_var_dir.mkdir(parents=True, exist_ok=True)

fp8_supported, gpu_info = check_fp8_support()
print(f"FP8 Support: {fp8_supported}")
print(gpu_info)

# Note: If FP8 is not supported, you may want to disable it in the model config
# The Evo2 config has 'use_fp8_input_projections: True' by default

if FAST_CI_MODE:
    model_subset_option = "--num-layers 4 --hybrid-override-pattern SDH*"
else:
    model_subset_option = ""

fp8_option = "--fp8" if fp8_supported else ""

# Update predict commands to run on the full dataset
# predict_ref_command = (
#     f"predict_evo2 --fasta {ref_fasta_path} --ckpt-dir {checkpoint_path} "
#     f"--output-dir {predict_ref_dir} --model-size {MODEL_SIZE} --tensor-parallel-size 1  {model_subset_option} "
#     f"--pipeline-model-parallel-size 1 --context-parallel-size 1 --output-log-prob-seqs {fp8_option}"
# )

# predict_var_command = (
#     f"predict_evo2 --fasta {var_fasta_path} --ckpt-dir {checkpoint_path} "
#     f"--output-dir {predict_var_dir} --model-size {MODEL_SIZE} --tensor-parallel-size 1 {model_subset_option} "
#     f"--pipeline-model-parallel-size 1 --context-parallel-size 1 --output-log-prob-seqs {fp8_option}"
# )


# TP = 8 CP = 2
predict_ref_command = (
    f"predict_evo2 --fasta {ref_fasta_path} --ckpt-dir {checkpoint_path} "
    f"--output-dir {predict_ref_dir} --model-size {MODEL_SIZE} --tensor-parallel-size 4  {model_subset_option} "
    f"--pipeline-model-parallel-size 1 --context-parallel-size 2 --output-log-prob-seqs {fp8_option}"
)

predict_var_command = (
    f"predict_evo2 --fasta {var_fasta_path} --ckpt-dir {checkpoint_path} "
    f"--output-dir {predict_var_dir} --model-size {MODEL_SIZE} --tensor-parallel-size 4 {model_subset_option} "
    f"--pipeline-model-parallel-size 1 --context-parallel-size 2 --output-log-prob-seqs {fp8_option}"
)
# Out:
# FP8 Support: True
# Device: NVIDIA B200, Compute Capability: 10.0

# %% [markdown]
# Score reference sequences:

# %%
predict_ref_command
# Out:
# 'predict_evo2 --fasta brca1_fasta_files/brca1_reference_sequences.fasta --ckpt-dir /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar --output-dir brca1_fasta_files/reference_predictions --model-size 40b_arc_longcontext --tensor-parallel-size 4   --pipeline-model-parallel-size 1 --context-parallel-size 2 --output-log-prob-seqs --fp8'

# %%
# %%capture
print(f"Running command: {predict_ref_command}")

result = run_subprocess_safely(predict_ref_command)
# Out:
# Running command: predict_evo2 --fasta brca1_fasta_files/brca1_reference_sequences.fasta --ckpt-dir /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar --output-dir brca1_fasta_files/reference_predictions --model-size 40b_arc_longcontext --tensor-parallel-size 4   --pipeline-model-parallel-size 1 --context-parallel-size 2 --output-log-prob-seqs --fp8
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Using byte-level tokenization
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Experiments will be logged at /tmp/tmpzdyv2aaa/default
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has data parallel group : [0]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has combined group of data parallel and context parallel : [0, 4]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All data parallel group ranks with context parallel combined: [[0, 4], [1, 5], [2, 6], [3, 7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Ranks 0 has data parallel rank: 0
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has context parallel group: [0, 4]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All context parallel group ranks: [[0, 4], [1, 5], [2, 6], [3, 7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Ranks 0 has context parallel rank: 0
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has model parallel group: [0, 1, 2, 3]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All model parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has tensor model parallel group: [0, 1, 2, 3]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All tensor model parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All expert tensor parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has expert tensor parallel rank: 0
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has pipeline model parallel group: [0]
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# [NeMo W 2025-11-05 00:25:39 nemo_logging:405] No version folders would be created under the log folder as 'resume_if_exists' is enabled.
# [NeMo W 2025-11-05 00:25:39 nemo_logging:405] "update_logger_directory" is True. Overwriting tensorboard logger "save_dir" to /tmp/tmpzdyv2aaa
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has embedding group: [0]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All pipeline model parallel group ranks: [[0], [1], [2], [3], [4], [5], [6], [7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] All embedding group ranks: [[0], [1], [2], [3], [4], [5], [6], [7]]
# [NeMo I 2025-11-05 00:25:39 nemo_logging:393] Rank 0 has embedding rank: 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#     return getattr(imported_module, symbol), True
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#     return getattr(imported_module, symbol), True
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# INFO:pytorch_lightning.utilities.rank_zero:----------------------------------------------------------------------------------------------------
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# distributed_backend=nccl
# All distributed processes registered. Starting with 8 processes
# ----------------------------------------------------------------------------------------------------
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [NeMo I 2025-11-05 00:25:56 num_microbatches_calculator:228] setting number of microbatches to constant 1
# [NeMo W 2025-11-05 00:26:01 nemo_logging:405] Multi-GPU predictions could result in shuffled inputs. Verify that the original indices are included in the model's predictions as outputs are not ordered and batch indices do not track input order.
# [NeMo I 2025-11-05 00:26:01 nemo_logging:393] Padded vocab_size: 512, original vocab_size: 512, dummy tokens: 0.
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo W 2025-11-05 00:26:01 nemo_logging:405] Could not copy Trainer's 'max_steps' to LR scheduler's 'max_steps'. If you are not using an LR scheduler, this warning can safely be ignored.
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo I 2025-11-05 00:26:01 nemo_logging:393]  > number of parameters on (tensor, pipeline) model parallel rank (0 ,0): 10280780032
# [NeMo I 2025-11-05 00:26:01 utils:661] Setting up DistributedDataParallel with config DistributedDataParallelConfig(grad_reduce_in_fp32=False, overlap_grad_reduce=False, overlap_param_gather=False, align_param_gather=False, use_distributed_optimizer=False, num_distributed_optimizer_instances=1, check_for_nan_in_grad=True, check_for_large_grads=False, bucket_size=None, pad_buckets_for_high_nccl_busbw=False, average_in_collective=False, fp8_param_gather=False, reuse_grad_buf_for_mxfp8_param_ag=False, use_custom_fsdp=False, data_parallel_sharding_strategy='no_shard', gradient_reduce_div_fusion=True, suggested_communication_unit_size=None, preserve_fp32_weights=True, keep_fp8_transpose_cache_when_using_custom_fsdp=False, nccl_ub=False, fsdp_double_buffer=False)
# [NeMo I 2025-11-05 00:26:01 utils:682] Number of buckets for gradient all-reduce / reduce-scatter: 1
#     Params for bucket 1 (10280780032 elements, 10280780032 padded size):
#     	module.decoder.layers.47.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.32.mlp.linear_fc1.weight
#     	module.decoder.layers.17.mlp.linear_fc2.weight
#     	module.decoder.layers.44.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.29.mixer.dense.bias
#     	module.decoder.layers.14.mixer.dense.bias
#     	module.decoder.layers.49.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.40.mixer.dense_projection.weight
#     	module.decoder.layers.25.mixer.dense_projection.weight
#     	module.decoder.layers.19.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mixer.dense.bias
#     	module.decoder.layers.30.mixer.dense.weight
#     	module.decoder.layers.1.mixer.dense_projection.weight
#     	module.decoder.layers.41.mlp.linear_fc2.weight
#     	module.decoder.layers.27.mixer.dense_projection.weight
#     	module.decoder.layers.22.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.13.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.6.mixer.dense.weight
#     	module.decoder.layers.38.mixer.mixer.filter.R
#     	module.decoder.layers.32.mlp.linear_fc2.weight
#     	module.decoder.layers.9.mixer.dense.bias
#     	module.decoder.layers.2.mlp.linear_fc1.weight
#     	module.decoder.layers.40.mixer.mixer.conv_bias
#     	module.decoder.layers.25.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.19.mlp.linear_fc2.weight
#     	module.decoder.layers.45.mlp.linear_fc1.weight
#     	module.decoder.layers.30.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.1.mixer.mixer.conv_bias
#     	module.decoder.layers.44.mixer.mixer.conv_bias
#     	module.decoder.layers.36.mlp.linear_fc1.weight
#     	module.decoder.layers.27.mixer.mixer.conv_bias
#     	module.decoder.layers.22.mixer.mixer.filter.h
#     	module.decoder.layers.6.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.47.mlp.linear_fc1.weight
#     	module.decoder.layers.38.mixer.mixer.filter.p
#     	module.decoder.layers.33.mixer.dense.bias
#     	module.decoder.layers.23.mixer.dense.bias
#     	module.decoder.layers.8.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.2.mlp.linear_fc2.weight
#     	module.decoder.layers.44.mixer.dense_projection.weight
#     	module.decoder.layers.29.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.14.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.49.mlp.linear_fc1.weight
#     	module.decoder.layers.41.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.34.mixer.dense.weight
#     	module.decoder.layers.25.mixer.dense.weight
#     	module.decoder.layers.10.self_attention.linear_qkv.weight
#     	module.decoder.layers.5.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.45.mlp.linear_fc2.weight
#     	module.decoder.layers.31.self_attention.linear_proj.weight
#     	module.decoder.layers.16.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.42.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.36.mlp.linear_fc2.weight
#     	module.decoder.layers.13.mixer.dense.bias
#     	module.decoder.layers.47.mlp.linear_fc2.weight
#     	module.decoder.layers.23.mixer.mixer.filter.R
#     	module.decoder.layers.18.mixer.dense.bias
#     	module.decoder.layers.9.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers
mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.13.mixer.mixer.filter.gamma
#     	module.decoder.layers.7.mlp.linear_fc1.weight
#     	module.decoder.layers.19.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.48.mixer.dense.weight
#     	module.decoder.layers.39.mixer.dense.weight
#     	module.decoder.layers.24.self_attention.linear_qkv.weight
#     	module.decoder.layers.9.mixer.mixer.filter.p
#     	module.decoder.layers.4.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.45.mixer.dense_projection.weight
#     	module.decoder.layers.30.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.15.mixer.dense_projection.weight
#     	module.decoder.layers.27.mixer.dense.bias
#     	module.decoder.layers.12.mixer.mixer.filter.h
#     	module.decoder.layers.6.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.32.mixer.dense.bias
#     	module.decoder.layers.16.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mixer.mixer.conv_bias
#     	module.decoder.layers.43.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.37.mlp.linear_fc2.weight
#     	module.decoder.layers.28.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.13.mixer.mixer.filter.R
#     	module.decoder.layers.7.mlp.linear_fc2.weight
#     	module.decoder.layers.48.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.40.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.24.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.4.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.42.self_attention.linear_proj.bias
#     	module.decoder.layers.45.mixer.mixer.conv_bias
#     	module.decoder.layers.1.mixer.mixer.filter.h
#     	module.decoder.layers.41.mixer.mixer.filter.gamma
#     	module.decoder.layers.26.mixer.dense.weight
#     	module.decoder.layers.20.mlp.linear_fc1.weight
#     	module.decoder.layers.8.mixer.mixer.conv_bias
#     	module.decoder.layers.47.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.32.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.19.mixer.mixer.conv_bias
#     	module.decoder.layers.43.mixer.dense.weight
#     	module.decoder.layers.28.mixer.dense_projection.weight
#     	module.decoder.layers.22.mlp.linear_fc1.weight
#     	module.decoder.layers.13.mixer.mixer.filter.p
#     	module.decoder.layers.8.mixer.dense.weight
#     	module.decoder.layers.19.mixer.dense_projection.weight
#     	module.decoder.layers.49.self_attention.linear_proj.weight
#     	module.decoder.layers.40.mixer.mixer.filter.h
#     	module.decoder.layers.34.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.25.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.4.mixer.dense_projection.weight
#     	module.decoder.layers.30.mixer.dense_projection.weight
#     	module.decoder.layers.16.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.1.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.20.mlp.linear_fc2.weight
#     	module.decoder.layers.41.mixer.mixer.filter.R
#     	module.decoder.layers.36.mixer.dense.bias
#     	module.decoder.layers.26.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.11.mlp.linear_fc1.weight
#     	module.decoder.layers.6.mixer.dense_projection.weight
#     	module.decoder.layers.32.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.17.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.2.mixer.mixer.filter.gamma
#     	module.decoder.layers.44.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.28.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.22.mlp.linear_fc2.weight
#     	module.decoder.layers.14.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.48.mlp.linear_fc1.weight
#     	module.decoder.layers.24.mlp.linear_fc1.weight
#     	module.decoder.layers.9.mixer.dense.weight
#     	module.decoder.layers.4.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.45.mixer.mixer.filter.gamma
#     	module.decoder.layers.30.mixer.mixer.conv_bias
#     	module.decoder.layers.0.mlp.linear_fc1.weight
#     	module.decoder.layers.41.mixer.mixer.filter.p
#     	module.decoder.layers.36.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.21.mixer.dense.bias
#     	module.decoder.layers.11.mlp.linear_fc2.weight
#     	module.decoder.layers.6.mixer.mixer.conv_bias
#     	module.decoder.final_norm.weight
#     	module.decoder.layers.47.mixer.dense_projection.weight
#     	module.decoder.layers.32.mixer.dense_projection.weight
#     	module.decoder.layers.2.mixer.mixer.filter.R
#     	module.decoder.layers.44.mixer.mixer.filter.h
#     	module.decoder.layers.38.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.28.mixer.dense.weight
#     	module.decoder.layers.8.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.48.mlp.linear_fc2.weight
#     	module.decoder.layers.39.mlp.linear_fc1.weight
#     	module.decoder.layers.34.mixer.dense_projection.weight
#     	module.decoder.layers.24.mlp.linear_fc2.weight
#     	module.decoder.layers.20.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.9.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.4.mixer.dense.weight
#     	module.decoder.layers.45.mixer.mixer.filter.R
#     	module.decoder.layers.16.mixer.dense.bias
#     	module.decoder.layers.0.mixer.dense.weight
#     	module.decoder.layers.36.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.26.mlp.linear_fc1.weight
#     	module.decoder.layers.12.mixer.dense.bias
#     	module.decoder.layers.32.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.2.mixer.mixer.filter.p
#     	module.decoder.layers.23.mixer.mixer.filter.gamma
#     	module.decoder.layers.38.mixer.dense.bias
#     	module.decoder.layers.29.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.13.mixer.dense.weight
#     	module.decoder.layers.39.mlp.linear_fc2.weight
#     	module.decoder.layers.34.mixer.mixer.conv_bias
#     	module.decoder.layers.10.self_attention.linear_proj.weight
#     	module.decoder.layers.5.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.45.mixer.mixer.filter.p
#     	module.decoder.layers.30.mixer.mixer.filter.gamma
#     	module.decoder.layers.15.mixer.dense.weight
#     	module.decoder.layers.0.mlp.linear_fc2.weight
#     	module.decoder.layers.36.mixer.dense_projection.weight
#     	module.decoder.layers.26.mlp.linear_fc2.weight
#     	module.decoder.layers.21.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.6.mixer.mixer.filter.gamma
#     	module.decoder.layers.48.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.32.mixer.dense.weight
#     	module.decoder.layers.17.self_attention.linear_qkv.weight
#     	module.decoder.layers.5.mixer.mixer.conv_bias
#     	module.decoder.layers.23.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.43.mlp.linear_fc1.weight
#     	module.decoder.layers.38.mixer.dense_projection.weight
#     	module.decoder.layers.29.mixer.mixer.filter.h
#     	module.decoder.layers.13.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.8.mixer.dense_projection.weight
#     	module.decoder.layers.49.self_attention.linear_qkv.layer_norm_weight
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar/weights
# [NeMo W 2025-11-05 00:26:03 serialization:184] DEPRECATED: Passing 'checkpoint_dir' as a Path object in load_common_state_dict will no longer be supported in a future release. Please pass it as a string instead.
#     	module.decoder.layers.20.mixer.dense.bias
#     	module.decoder.layers.9.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mixer.mixer.filter.h
#     	module.decoder.layers.46.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.30.mixer.mixer.filter.R
#     	module.decoder.layers.15.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.2.mixer.dense.bias
#     	module.decoder.layers.41.mixer.dense.weight
#     	module.decoder.layers.36.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.21.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.12.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.6.mixer.mixer.filter.R
#     	module.decoder.layers.33.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.17.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.43.mlp.linear_fc2.weight
#     	module.decoder.layers.38.mixer.mixer.conv_bias
#     	module.decoder.layers.34.mixer.mixer.filter.gamma
#     	module.decoder.layers.25.mixer.dense.bias
#     	module.decoder.layers.19.mixer.dense.weight
#     	module.decoder.layers.9.mlp.linear_fc2.weight
#     	module.decoder.layers.30.mixer.mixer.filter.p
#     	module.embedding.word_embeddings.weight
#     	module.decoder.layers.41.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.36.mixer.dense.weight
#     	module.decoder.layers.21.mixer.dense_projection.weight
#     	module.decoder.layers.6.mixer.mixer.filter.p
#     	module.decoder.layers.48.mixer.dense.bias
#     	module.decoder.layers.33.mixer.mixer.filter.h
#     	module.decoder.layers.18.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.2.mixer.dense.weight
#     	module.decoder.layers.44.mixer.dense.bias
#     	module.decoder.layers.28.mlp.linear_fc1.weight
#     	module.decoder.layers.23.mixer.dense_projection.weight
#     	module.decoder.layers.13.mlp.linear_fc1.weight
#     	module.decoder.layers.8.mixer.dense.bias
#     	module.decoder.layers.40.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.34.mixer.mixer.filter.R
#     	module.decoder.layers.25.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.19.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.12.mixer.mixer.conv_bias
#     	module.decoder.layers.4.mlp.linear_fc1.weight
#     	module.decoder.layers.45.mixer.dense.weight
#     	module.decoder.layers.15.mlp.linear_fc1.weight
#     	module.decoder.layers.1.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.42.self_attention.linear_proj.weight
#     	module.decoder.layers.37.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.27.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.21.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.12.mixer.dense_projection.weight
#     	module.decoder.layers.7.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.47.mixer.dense.weight
#     	module.decoder.layers.17.mlp.linear_fc1.weight
#     	module.decoder.layers.2.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.23.mixer.mixer.conv_bias
#     	module.decoder.layers.38.mixer.mixer.filter.gamma
#     	module.decoder.layers.28.mlp.linear_fc2.weight
#     	module.decoder.layers.13.mlp.linear_fc2.weight
#     	module.decoder.layers.49.self_attention.linear_qkv.weight
#     	module.decoder.layers.34.mixer.mixer.filter.p
#     	module.decoder.layers.25.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.10.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.4.mlp.linear_fc2.weight
#     	module.decoder.layers.45.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.15.mlp.linear_fc2.weight
#     	module.decoder.layers.41.mlp.linear_fc1.weight
#     	module.decoder.layers.37.mixer.mixer.filter.h
#     	module.decoder.layers.29.mixer.mixer.conv_bias
#     	module.decoder.layers.21.mixer.dense.weight
# [NeMo I 2025-11-05 00:26:03 nemo_logging:393] Loaded sharded_state_dict_metadata from checkpoint: {'distrib_optim_sharding_type': 'fully_sharded_model_space'}
# [NeMo I 2025-11-05 00:26:03 nemo_logging:393] Using <megatron.core.dist_checkpointing.strategies.fully_parallel.FullyParallelLoadStrategyWrapper object at 0x78f0b813c3e0> dist-ckpt load strategy.
# [NeMo I 2025-11-05 00:26:31 nemo_logging:393] Global Checkpoint Load : Rank : 0 : Start time : 1762302363.876s : Time spent in load_checkpoint: 27.321s
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar/weights
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# [NeMo I 2025-11-05 00:26:59 nemo_logging:393] Inference predictions are stored in brca1_fasta_files/reference_predictions/predictions__rank_0__dp_rank_0.pt
#     dict_keys(['log_probs_seqs', 'seq_idx'])

# %%
assert result["returncode"] == 0, result

# %% [markdown]
# Score variant sequences:

# %%
# %%capture
print(f"Running command: {predict_var_command}")

result = run_subprocess_safely(predict_var_command)
# Out:
# Running command: predict_evo2 --fasta brca1_fasta_files/brca1_variant_sequences.fasta --ckpt-dir /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar --output-dir brca1_fasta_files/variant_predictions --model-size 40b_arc_longcontext --tensor-parallel-size 4  --pipeline-model-parallel-size 1 --context-parallel-size 2 --output-log-prob-seqs --fp8
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Using byte-level tokenization
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Experiments will be logged at /tmp/tmpofrnldwy/default
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has data parallel group : [0]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has combined group of data parallel and context parallel : [0, 4]
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# [NeMo W 2025-11-05 00:28:37 nemo_logging:405] No version folders would be created under the log folder as 'resume_if_exists' is enabled.
# [NeMo W 2025-11-05 00:28:37 nemo_logging:405] "update_logger_directory" is True. Overwriting tensorboard logger "save_dir" to /tmp/tmpofrnldwy
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All data parallel group ranks with context parallel combined: [[0, 4], [1, 5], [2, 6], [3, 7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Ranks 0 has data parallel rank: 0
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has context parallel group: [0, 4]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All context parallel group ranks: [[0, 4], [1, 5], [2, 6], [3, 7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Ranks 0 has context parallel rank: 0
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has model parallel group: [0, 1, 2, 3]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All model parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has tensor model parallel group: [0, 1, 2, 3]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All tensor model parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All expert tensor parallel group ranks: [[0, 1, 2, 3], [4, 5, 6, 7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has expert tensor parallel rank: 0
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has embedding group: [0]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All pipeline model parallel group ranks: [[0], [1], [2], [3], [4], [5], [6], [7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] All embedding group ranks: [[0], [1], [2], [3], [4], [5], [6], [7]]
# [NeMo I 2025-11-05 00:28:37 nemo_logging:393] Rank 0 has embedding rank: 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# INFO:nemo.utils.import_utils:Import of quick_gelu from megatron.core.fusions.fused_bias_geglu failed with: Traceback (most recent call last):
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
#   File "/usr/local/lib/python3.12/dist-packages/nemo/utils/import_utils.py", line 319, in safe_import_from
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
#     return getattr(imported_module, symbol), True
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'megatron.core.fusions.fused_bias_geglu' has no attribute 'quick_gelu'
#
# INFO:pytorch_lightning.utilities.rank_zero:----------------------------------------------------------------------------------------------------
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# distributed_backend=nccl
# All distributed processes registered. Starting with 8 processes
# ----------------------------------------------------------------------------------------------------
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [Gloo] Rank 0 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [NeMo W 2025-11-05 00:28:59 nemo_logging:405] Multi-GPU predictions could result in shuffled inputs. Verify that the original indices are included in the model's predictions as outputs are not ordered and batch indices do not track input order.
# [NeMo I 2025-11-05 00:28:55 num_microbatches_calculator:228] setting number of microbatches to constant 1
# [Gloo] Rank 1 is connected to 1 peer ranks. Expected number of connected peer ranks is : 1
# [NeMo I 2025-11-05 00:28:59 nemo_logging:393] Padded vocab_size: 512, original vocab_size: 512, dummy tokens: 0.
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 7 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 4 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo W 2025-11-05 00:28:59 nemo_logging:405] Could not copy Trainer's 'max_steps' to LR scheduler's 'max_steps'. If you are not using an LR scheduler, this warning can safely be ignored.
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 6 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# LOCAL_RANK: 5 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# [NeMo I 2025-11-05 00:28:59 nemo_logging:393]  > number of parameters on (tensor, pipeline) model parallel rank (0 ,0): 10280780032
# [NeMo I 2025-11-05 00:28:59 utils:661] Setting up DistributedDataParallel with config DistributedDataParallelConfig(grad_reduce_in_fp32=False, overlap_grad_reduce=False, overlap_param_gather=False, align_param_gather=False, use_distributed_optimizer=False, num_distributed_optimizer_instances=1, check_for_nan_in_grad=True, check_for_large_grads=False, bucket_size=None, pad_buckets_for_high_nccl_busbw=False, average_in_collective=False, fp8_param_gather=False, reuse_grad_buf_for_mxfp8_param_ag=False, use_custom_fsdp=False, data_parallel_sharding_strategy='no_shard', gradient_reduce_div_fusion=True, suggested_communication_unit_size=None, preserve_fp32_weights=True, keep_fp8_transpose_cache_when_using_custom_fsdp=False, nccl_ub=False, fsdp_double_buffer=False)
# [NeMo I 2025-11-05 00:28:59 utils:682] Number of buckets for gradient all-reduce / reduce-scatter: 1
#     Params for bucket 1 (10280780032 elements, 10280780032 padded size):
#     	module.decoder.layers.34.mlp.linear_fc1.weight
#     	module.decoder.layers.22.mixer.mixer.conv_bias
#     	module.decoder.layers.46.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.33.mixer.mixer.conv_bias
#     	module.decoder.layers.16.mixer.mixer.conv_bias
#     	module.decoder.layers.1.mixer.dense.weight
#     	module.decoder.layers.42.self_attention.linear_qkv.weight
#     	module.decoder.layers.37.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.27.mixer.mixer.filter.p
#     	module.decoder.layers.22.mixer.dense.bias
#     	module.decoder.layers.7.mixer.dense.bias
#     	module.decoder.layers.48.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.33.mixer.dense_projection.weight
#     	module.decoder.layers.18.mixer.dense_projection.weight
#     	module.decoder.layers.45.mixer.dense.bias
#     	module.decoder.layers.30.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.23.mixer.dense.weight
#     	module.decoder.layers.14.mixer.dense.weight
#     	module.decoder.layers.40.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.34.mlp.linear_fc2.weight
#     	module.decoder.layers.20.mixer.dense_projection.weight
#     	module.decoder.layers.26.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.11.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.6.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.46.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.31.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.42.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.28.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.12.mlp.linear_fc1.weight
#     	module.decoder.layers.18.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.44.mixer.dense.weight
#     	module.decoder.layers.38.mlp.linear_fc1.weight
#     	module.decoder.layers.23.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.15.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.40.mlp.linear_fc2.weight
#     	module.decoder.layers.37.mixer.mixer.conv_bias
#     	module.decoder.layers.20.mixer.mixer.conv_bias
#     	module.decoder.layers.46.mixer.dense_projection.weight
#     	module.decoder.layers.16.mixer.mixer.filter.gamma
#     	module.decoder.layers.43.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.37.mixer.dense_projection.weight
#     	module.decoder.layers.22.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.12.mlp.linear_fc2.weight
#     	module.decoder.layers.7.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.48.mixer.dense_projection.weight
#     	module.decoder.layers.34.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.18.mixer.dense.weight
#     	module.decoder.layers.3.self_attention.linear_qkv.weight
#     	module.decoder.layers.44.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.38.mlp.linear_fc2.weight
#     	module.decoder.layers.30.mixer.dense.bias
#     	module.decoder.layers.24.self_attention.linear_proj.weight
#     	module.decoder.layers.15.mixer.mixer.filter.h
#     	module.decoder.layers.9.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.41.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.35.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.12.mixer.mixer.filter.h
#     	module.decoder.layers.6.mixer.dense.bias
#     	module.decoder.layers.46.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.16.mixer.mixer.filter.R
#     	module.decoder.layers.1.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.42.mlp.linear_fc1.weight
#     	module.decoder.layers.27.mixer.dense.weight
#     	module.decoder.layers.7.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.19.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.48.mixer.mixer.conv_bias
#     	module.decoder.layers.3.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.39.mixer.dense.bias
#     	module.decoder.layers.29.mixer.dense.weight
#     	module.decoder.layers.24.self_attention.linear_proj.bias
#     	module.decoder.layers.23.mlp.linear_fc1.weight
#     	module.decoder.layers.20.mixer.mixer.filter.gamma
#     	module.decoder.layers.11.mixer.dense.bias
#     	module.decoder.layers.5.mixer.dense.weight
#     	module.decoder.layers.46.mixer.dense.weight
#     	module.decoder.layers.31.self_attention.linear_qkv.weight
#     	module.decoder.layers.16.mixer.mixer.filter.p
#     	module.decoder.layers.2.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.22.mixer.dense_projection.weight
#     	module.decoder.layers.42.mlp.linear_fc2.weight
#     	module.decoder.layers.38.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers
mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.28.mixer.dense.bias
#     	module.decoder.layers.23.mixer.dense.bias
#     	module.decoder.layers.13.mixer.mixer.conv_bias
#     	module.decoder.layers.8.mixer.mixer.filter.h
#     	module.decoder.layers.33.mlp.linear_fc1.weight
#     	module.decoder.layers.19.mixer.dense.bias
#     	module.decoder.layers.0.mixer.dense.weight
#     	module.decoder.layers.45.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.39.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.15.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.9.mixer.mixer.filter.R
#     	module.decoder.layers.0.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.41.mixer.dense_projection.weight
#     	module.decoder.layers.35.mlp.linear_fc1.weight
#     	module.decoder.layers.27.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.20.mixer.dense.weight
#     	module.decoder.layers.11.mixer.dense.weight
#     	module.decoder.layers.46.mlp.linear_fc2.weight
#     	module.decoder.layers.17.self_attention.linear_proj.weight
#     	module.decoder.layers.43.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.22.mixer.dense.weight
#     	module.decoder.layers.33.mlp.linear_fc2.weight
#     	module.decoder.layers.4.mixer.dense.bias
#     	module.decoder.layers.3.self_attention.linear_proj.bias
#     	module.decoder.layers.47.mixer.mixer.conv_bias
#     	module.decoder.layers.39.mixer.dense.weight
#     	module.decoder.layers.24.self_attention.linear_qkv.weight
#     	module.decoder.layers.9.mixer.mixer.filter.p
#     	module.decoder.layers.1.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.20.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.41.mixer.mixer.conv_bias
#     	module.decoder.layers.35.mlp.linear_fc2.weight
#     	module.decoder.layers.26.mixer.dense.bias
#     	module.decoder.layers.12.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.47.mixer.dense.bias
#     	module.decoder.layers.16.mlp.linear_fc1.weight
#     	module.decoder.layers.2.mixer.dense_projection.weight
#     	module.decoder.layers.43.mixer.dense_projection.weight
#     	module.decoder.layers.37.mlp.linear_fc1.weight
#     	module.decoder.layers.28.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.22.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.13.mixer.mixer.filter.gamma
#     	module.decoder.layers.7.mlp.linear_fc1.weight
#     	module.decoder.layers.48.mixer.dense.weight
#     	module.decoder.layers.19.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.4.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.45.mixer.dense_projection.weight
#     	module.decoder.layers.40.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.30.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.24.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.15.mixer.dense_projection.weight
#     	module.decoder.layers.27.mixer.dense.bias
#     	module.decoder.layers.6.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.32.mixer.dense.bias
#     	module.decoder.layers.16.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mixer.mixer.conv_bias
#     	module.decoder.layers.43.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.37.mlp.linear_fc2.weight
#     	module.decoder.layers.28.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.13.mixer.mixer.filter.R
#     	module.decoder.layers.7.mlp.linear_fc2.weight
#     	module.decoder.layers.48.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.4.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.45.mixer.mixer.conv_bias
#     	module.decoder.layers.42.self_attention.linear_proj.bias
#     	module.decoder.layers.40.mixer.mixer.filter.h
#     	module.decoder.layers.25.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.0.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.20.mlp.linear_fc1.weight
#     	module.decoder.layers.41.mixer.mixer.filter.gamma
#     	module.decoder.layers.26.mixer.dense.weight
#     	module.decoder.layers.8.mixer.mixer.conv_bias
#     	module.decoder.layers.47.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.32.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.19.mixer.mixer.conv_bias
#     	module.decoder.layers.43.mixer.dense.weight
#     	module.decoder.layers.28.mixer.dense_projection.weight
#     	module.decoder.layers.22.mlp.linear_fc1.weight
#     	module.decoder.layers.13.mixer.mixer.filter.p
#     	module.decoder.layers.8.mixer.dense.bias
#     	module.decoder.layers.19.mixer.dense_projection.weight
#     	module.decoder.layers.49.self_attention.linear_proj.weight
#     	module.decoder.layers.34.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers
mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.13.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.8.mixer.dense_projection.weight
#     	module.decoder.layers.49.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.20.mixer.dense.bias
#     	module.decoder.layers.5.mixer.mixer.filter.h
#     	module.decoder.layers.46.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.30.mixer.mixer.filter.R
#     	module.decoder.layers.25.mixer.dense.bias
#     	module.decoder.layers.15.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.9.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mixer.dense.bias
#     	module.decoder.layers.41.mixer.dense.weight
#     	module.decoder.layers.36.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.21.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.12.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.6.mixer.mixer.filter.R
#     	module.decoder.layers.33.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.17.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.43.mlp.linear_fc2.weight
#     	module.decoder.layers.38.mixer.mixer.conv_bias
#     	module.decoder.layers.35.self_attention.linear_proj.bias
#     	module.decoder.layers.34.mixer.mixer.filter.gamma
#     	module.decoder.layers.19.mixer.dense.weight
#     	module.decoder.layers.40.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.30.mixer.mixer.filter.p
#     	module.decoder.layers.26.mixer.mixer.filter.h
#     	module.decoder.layers.25.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.41.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.36.mixer.dense.weight
#     	module.decoder.layers.21.mixer.dense_projection.weight
#     	module.decoder.layers.6.mixer.mixer.filter.p
#     	module.decoder.layers.48.mixer.dense.bias
#     	module.decoder.layers.33.mixer.mixer.filter.h
#     	module.decoder.layers.18.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.2.mixer.dense.weight
#     	module.decoder.layers.44.mixer.dense.bias
#     	module.decoder.layers.28.mlp.linear_fc1.weight
#     	module.decoder.layers.23.mixer.dense_projection.weight
#     	module.decoder.layers.13.mlp.linear_fc1.weight
#     	module.decoder.layers.9.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.34.mixer.mixer.filter.R
#     	module.decoder.layers.19.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.4.mlp.linear_fc1.weight
#     	module.decoder.layers.45.mixer.dense.weight
#     	module.decoder.layers.25.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.15.mlp.linear_fc1.weight
#     	module.decoder.layers.10.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.1.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.42.self_attention.linear_proj.weight
#     	module.decoder.layers.37.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.27.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.21.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.12.mixer.dense_projection.weight
#     	module.decoder.layers.7.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.47.mixer.dense.weight
#     	module.decoder.layers.17.mlp.linear_fc1.weight
#     	module.decoder.layers.2.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.38.mixer.mixer.filter.gamma
#     	module.decoder.layers.28.mlp.linear_fc2.weight
#     	module.decoder.layers.23.mixer.mixer.conv_bias
#     	module.decoder.layers.13.mlp.linear_fc2.weight
#     	module.decoder.layers.49.self_attention.linear_qkv.weight
#     	module.decoder.layers.34.mixer.mixer.filter.p
#     	module.decoder.layers.4.mlp.linear_fc2.weight
#     	module.decoder.layers.45.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.40.mixer.dense_projection.weight
#     	module.decoder.layers.25.mixer.dense_projection.weight
#     	module.decoder.layers.15.mlp.linear_fc2.weight
#     	module.decoder.layers.10.mlp.linear_fc1.weight
#     	module.decoder.layers.41.mlp.linear_fc1.weight
#     	module.decoder.layers.37.mixer.mixer.filter.h
#     	module.decoder.layers.29.mixer.mixer.conv_bias
#     	module.decoder.layers.21.mixer.dense.weight
#     	module.decoder.layers.12.mixer.mixer.conv_bias
#     	module.decoder.layers.47.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.32.mlp.linear_fc1.weight
#     	module.decoder.layers.17.mlp.linear_fc2.weight
#     	module.decoder.layers.44.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.38.mixer.mixer.filter.R
#     	module.decoder.layers.29.mixer.dense.bias
#     	module.decoder.layers.14.mixer.dense.bias
#     	module.decoder.layers.9.mixer.dense.bias
#     	module.decoder.layers.49.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.19.mlp.linear_fc1.weight
#     	module.decoder.layers.5.mixer.dense.bias
#     	module.decoder.layers.30.mixer.dense.weight
#     	module.decoder.layers.25.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.1.mixer.dense_projection.weight
#     	module.decoder.layers.22.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.41.mlp.linear_fc2.weight
#     	module.decoder.layers.27.mixer.dense_projection.weight
#     	module.decoder.layers.13.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.6.mixer.dense.weight
#     	module.decoder.layers.32.mlp.linear_fc2.weight
#     	module.decoder.layers.2.mlp.linear_fc1.weight
#     	module.decoder.layers.38.mixer.mixer.filter.p
#     	module.decoder.layers.23.mixer.mixer.filter.gamma
#     	module.decoder.layers.8.mixer.dense.weight
#     	module.decoder.layers.19.mlp.linear_fc2.weight
#     	module.decoder.layers.25.mixer.dense.weight
#     	module.decoder.layers.45.mlp.linear_fc1.weight
#     	module.decoder.layers.40.mixer.dense.bias
#     	module.decoder.layers.30.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.10.self_attention.linear_qkv.weight
#     	module.decoder.layers.1.mixer.mixer.conv_bias
#     	module.decoder.layers.44.mixer.mixer.conv_bias
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar/weights
# [NeMo W 2025-11-05 00:29:01 serialization:184] DEPRECATED: Passing 'checkpoint_dir' as a Path object in load_common_state_dict will no longer be supported in a future release. Please pass it as a string instead.
#     	module.decoder.layers.36.mlp.linear_fc1.weight
#     	module.decoder.layers.27.mixer.mixer.conv_bias
#     	module.decoder.layers.22.mixer.mixer.filter.h
#     	module.decoder.layers.12.mixer.dense.bias
#     	module.decoder.layers.6.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.0.mixer.dense_projection.weight
#     	module.decoder.layers.47.mlp.linear_fc1.weight
#     	module.decoder.layers.33.mixer.dense.bias
#     	module.decoder.layers.2.mlp.linear_fc2.weight
#     	module.decoder.layers.44.mixer.dense_projection.weight
#     	module.decoder.layers.39.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.29.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.23.mixer.mixer.filter.R
#     	module.decoder.layers.14.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.8.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.49.mlp.linear_fc1.weight
#     	module.decoder.layers.34.mixer.dense.weight
#     	module.decoder.layers.5.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.45.mlp.linear_fc2.weight
#     	module.decoder.layers.31.self_attention.linear_proj.weight
#     	module.decoder.layers.25.mlp.linear_fc1.weight
#     	module.decoder.layers.16.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.10.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.42.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.layers.36.mlp.linear_fc2.weight
#     	module.decoder.layers.13.mixer.dense.bias
#     	module.decoder.layers.47.mlp.linear_fc2.weight
#     	module.decoder.layers.18.mixer.dense.bias
#     	module.decoder.layers.3.self_attention.linear_proj.weight
#     	module.decoder.layers.23.mixer.mixer.filter.p
#     	module.decoder.layers.14.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.49.mlp.linear_fc2.weight
#     	module.decoder.layers.34.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.46.mixer.dense.bias
#     	module.decoder.layers.31.self_attention.linear_proj.bias
#     	module.decoder.layers.30.mlp.linear_fc1.weight
#     	module.decoder.layers.10.mlp.linear_fc2.weight
#     	module.decoder.layers.1.mixer.dense.bias
#     	module.decoder.layers.37.mixer.dense.bias
#     	module.decoder.layers.27.mixer.mixer.filter.gamma
#     	module.decoder.layers.21.mlp.linear_fc1.weight
#     	module.decoder.layers.12.mixer.dense.weight
#     	module.decoder.layers.6.mlp.linear_fc1.weight
#     	module.decoder.layers.33.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.18.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.3.self_attention.linear_qkv.layer_norm_weight
#     	module.decoder.final_norm.weight
#     	module.decoder.layers.45.mixer.hyena_proj_conv.short_conv_weight
#     	module.decoder.layers.38.mixer.dense.weight
#     	module.decoder.layers.29.mixer.dense_projection.weight
#     	module.decoder.layers.14.mixer.dense_projection.weight
#     	module.decoder.layers.8.mlp.linear_fc1.weight
#     	module.decoder.layers.35.self_attention.linear_proj.weight
#     	module.decoder.layers.20.mixer.dense_projection.layer_norm_weight
#     	module.decoder.layers.5.mixer.dense_projection.weight
#     	module.decoder.layers.40.mlp.linear_fc1.weight
#     	module.decoder.layers.30.mlp.linear_fc2.weight
#     	module.decoder.layers.25.mlp.linear_fc2.weight
#     	module.decoder.layers.16.mixer.dense_projection.weight
#     	module.decoder.layers.27.mixer.mixer.filter.R
#     	module.decoder.layers.21.mlp.linear_fc2.weight
#     	module.decoder.layers.12.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.6.mlp.linear_fc2.weight
#     	module.decoder.layers.18.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.38.mlp.linear_fc1.layer_norm_weight
#     	module.decoder.layers.14.mixer.mixer.short_conv.short_conv_weight
#     	module.decoder.layers.8.mlp.linear_fc2.weight
# [NeMo I 2025-11-05 00:29:01 nemo_logging:393] Loaded sharded_state_dict_metadata from checkpoint: {'distrib_optim_sharding_type': 'fully_sharded_model_space'}
# [NeMo I 2025-11-05 00:29:02 nemo_logging:393] Using <megatron.core.dist_checkpointing.strategies.fully_parallel.FullyParallelLoadStrategyWrapper object at 0x7e10c78ab830> dist-ckpt load strategy.
# [NeMo I 2025-11-05 00:29:28 nemo_logging:393] Global Checkpoint Load : Rank : 0 : Start time : 1762302542.006s : Time spent in load_checkpoint: 26.479s
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at /root/.cache/bionemo/544b47e033d1fb0261b686a53f7c4fe240cd290253187d31e8c99dea9e35a680-evo2_40b_bf16_finetune_wandb_Ji2IRcrz_step_119.tar.gz.untar/weights
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# WARNING:bionemo.llm.data.collate:Extra keys in batch that will not be padded: {'seq_idx'}. Missing keys in batch: set()
# [NeMo I 2025-11-05 00:29:56 nemo_logging:393] Inference predictions are stored in brca1_fasta_files/variant_predictions/predictions__rank_0__dp_rank_0.pt
#     dict_keys(['log_probs_seqs', 'seq_idx'])

# %%
assert result["returncode"] == 0, result

# %% [markdown]
# We calculate the change in likelihoods for each variant relative to the likelihood of their respective wild-type sequence.

# %% [markdown]
# First, we load the prediction files and sequence id maps:

# %%
# Find and load prediction files
ref_pred_files = glob.glob(os.path.join(predict_ref_dir, "predictions__rank_*.pt"))
var_pred_files = glob.glob(os.path.join(predict_var_dir, "predictions__rank_*.pt"))

# Load sequence ID maps (maps sequence ID -> prediction index)
with open(os.path.join(predict_ref_dir, "seq_idx_map.json"), "r") as f:
    ref_seq_idx_map = json.load(f)
with open(os.path.join(predict_var_dir, "seq_idx_map.json"), "r") as f:
    var_seq_idx_map = json.load(f)

# Load predictions
ref_preds = torch.load(ref_pred_files[0])
var_preds = torch.load(var_pred_files[0])

# %% [markdown]
# Then, calculate the delta score:

# %%
# next, calculate change in likelihoods
ref_log_probs = []
var_log_probs = []
for _, row in brca1_df.iterrows():
    ref_name = row["ref_fasta_name"]
    var_name = row["var_fasta_name"]
    ref_log_probs.append(ref_preds["log_probs_seqs"][ref_seq_idx_map[ref_name]].item())
    var_log_probs.append(var_preds["log_probs_seqs"][var_seq_idx_map[var_name]].item())
brca1_df["ref_log_probs"] = ref_log_probs
brca1_df["var_log_probs"] = var_log_probs
# ideally probability of a broken variant is lower than a good one. So a bad var - good ref is negative.
brca1_df["evo2_delta_score"] = brca1_df["var_log_probs"] - brca1_df["ref_log_probs"]
brca1_df.head()
# Out:
#    chrom       pos ref alt     score     class  \
# 0     17  41199726   T   C  0.159762  FUNC/INT
# 1     17  41209074   T   A -2.065569       LOF
# 2     17  41256913   A   C -0.847753  FUNC/INT
# 3     17  41219631   T   A -2.053739       LOF
# 4     17  41215965   G   A -1.671525       LOF
#
#                             ref_fasta_name  \
# 0  BRCA1_ref_pos_41199726_T_class_FUNC/INT
# 1       BRCA1_ref_pos_41209074_T_class_LOF
# 2  BRCA1_ref_pos_41256913_A_class_FUNC/INT
# 3       BRCA1_ref_pos_41219631_T_class_LOF
# 4       BRCA1_ref_pos_41215965_G_class_LOF
#
#                                var_fasta_name  ref_log_probs  var_log_probs  \
# 0  BRCA1_var_pos_41199726_TtoC_class_FUNC/INT      -0.872774      -0.873144
# 1       BRCA1_var_pos_41209074_TtoA_class_LOF      -0.721784      -0.727542
# 2  BRCA1_var_pos_41256913_AtoC_class_FUNC/INT      -0.743819      -0.746504
# 3       BRCA1_var_pos_41219631_TtoA_class_LOF      -0.946904      -0.969061
# 4       BRCA1_var_pos_41215965_GtoA_class_LOF      -0.803150      -0.804406
#
#    evo2_delta_score
# 0         -0.000370
# 1         -0.005758
# 2         -0.002685
# 3         -0.022156
# 4         -0.001256

# %% [markdown]
# This delta likelihood should be predictive of how disruptive the SNV is to the protein's function: the lower the delta, the more likely that the SNV is disruptive. We can show this by comparing the distributions of delta likelihoods for the two classes of SNVs (functional/intermediate vs loss-of-function).

# %%
def plot_strip_with_means(df, x_col="evo2_delta_score", class_col="class"):
    """Creates a strip plot with jittered points and median indicators for each class using Seaborn.

    Parameters:
    - df (pd.DataFrame): The input DataFrame containing data.
    - x_col (str): The column name representing the x-axis values (e.g., evo2_delta_score).
    - class_col (str): The column name representing the class labels.

    Returns:
    - matplotlib Figure: Strip plot with median indicators.
    """
    # NVIDIA theme colors
    NVIDIA_GREEN = "#76B900"
    BACKGROUND_COLOR = "#F8F8F8"
    GRID_COLOR = "#DDDDDD"
    FONT_COLOR = "#333333"

    # Determine order of classes (if not already specified)
    unique_classes = sorted(df[class_col].unique())

    # Set up the plot with NVIDIA theme
    plt.figure(figsize=(9, 5), facecolor=BACKGROUND_COLOR)
    plt.style.use("default")  # Reset to default to avoid any pre-existing style

    # Create strip plot
    p = sns.stripplot(
        data=df,
        x=x_col,
        y=class_col,
        hue=class_col,
        order=unique_classes,
        palette=[NVIDIA_GREEN, "red"],
        size=6,
        jitter=0.3,
        alpha=0.6,
    )

    # Add median indicators using boxplot
    sns.boxplot(
        showmeans=True,
        meanline=True,
        meanprops={"visible": False},
        medianprops={"color": "black", "ls": "-", "lw": 2},
        whiskerprops={"visible": False},
        zorder=10,
        x=x_col,
        y=class_col,
        data=df,
        order=unique_classes,
        showfliers=False,
        showbox=False,
        showcaps=False,
        ax=p,
    )

    # Customize plot appearance
    plt.title(
        "Distribution of Delta Likelihoods Scores\nComparing Evo 2 likelihood scores for different BRCA1 SNV classes",
        color=FONT_COLOR,
        fontsize=12,
        loc="left",
    )
    plt.xlabel("Delta Likelihood Score, Evo 2", color=FONT_COLOR)
    plt.ylabel("BRCA1 SNV Class", color=FONT_COLOR)

    # Customize grid and tick colors
    plt.grid(color=GRID_COLOR, axis="x", linestyle="--", linewidth=0.5)
    plt.tick_params(colors=FONT_COLOR)

    # Set background color
    plt.gca().set_facecolor(BACKGROUND_COLOR)
    plt.gcf().set_facecolor(BACKGROUND_COLOR)

    plt.tight_layout()

    # return plt.gcf()

# %%
plot_strip_with_means(brca1_df, x_col="evo2_delta_score", class_col="class")
# Out:
# 2025-11-05 00:31:21,818 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-11-05 00:31:21,819 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-11-05 00:31:21,827 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2025-11-05 00:31:21,827 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,828 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,829 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,829 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,829 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,829 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,829 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,830 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,830 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,830 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2025-11-05 00:31:21,830 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,830 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:21,831 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,832 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,832 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,832 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,832 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,833 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,834 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:21,835 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,836 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:21,837 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# 2025-11-05 00:31:21,875 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# 2025-11-05 00:31:21,876 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,876 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,877 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,878 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,878 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,879 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,880 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,880 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2025-11-05 00:31:21,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,882 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,883 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,883 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,884 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,885 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,885 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:21,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,887 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,887 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,888 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,889 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,890 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,890 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,891 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,893 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,893 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:21,894 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,894 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,895 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,896 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,897 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,897 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,898 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,898 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2025-11-05 00:31:21,899 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:21,899 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:21,900 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,901 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:21,901 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,902 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:21,903 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:21,903 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:21,904 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %% [markdown]
# We can also calculate the area under the receiver operating characteristic curve (AUROC) of this zero-shot prediction method. Note that the results are nearly random unless you are on one of the following configurations:
# * `--fp8` on an fp8 enabled GPU with either the 1b or 7b models. The 40b likely works as well.
# * the 7b model uniquely seems to work well without `--fp8` so if you are on an older device, the 7b model should produce
#   robust results. Change the `MODEL_SIZE` earlier in this tutorial and rerun for good results in that case.

# %%
# Calculate AUROC of zero-shot predictions
#  class 1 is LOF which is the bad thing. That means we expect this to be more negative.
y_true = brca1_df["class"] == "LOF"
auroc = roc_auc_score(y_true, -brca1_df["evo2_delta_score"])
print(f"Zero-shot prediction AUROC: {auroc:.2}")
# Out:
# Zero-shot prediction AUROC: 0.85

# %%
def plot_roc_curve(df):
    """Plots an ROC curve using Seaborn with a light NVIDIA-themed design.

    The function assumes:
    - `class` column as the true labels (binary, 'LOF' = 1, else 0).
    - `evo2_delta_score` as the prediction score.

    Parameters:
    - df (pd.DataFrame): DataFrame containing `class` and `evo2_delta_score`.

    Returns:
    - matplotlib Figure: ROC Curve Visualization.
    """
    # NVIDIA theme colors
    NVIDIA_GREEN = "#76B900"
    BACKGROUND_COLOR = "#F8F8F8"
    GRID_COLOR = "#DDDDDD"
    FONT_COLOR = "#333333"

    # Validate required columns
    if "class" not in df.columns or "evo2_delta_score" not in df.columns:
        raise ValueError("DataFrame must contain 'class' and 'evo2_delta_score' columns.")

    # Convert 'class' to binary labels: Assume 'LOF' = 1, anything else = 0
    y_true = (df["class"] == "LOF").astype(int)

    # Compute ROC curve
    fpr, tpr, _ = roc_curve(y_true, -df["evo2_delta_score"])  # Negative to align with previous logic
    roc_auc = auc(fpr, tpr)

    # Set up the plot with NVIDIA theme
    plt.figure(figsize=(9, 5), facecolor=BACKGROUND_COLOR)
    plt.style.use("default")  # Reset to default to avoid any pre-existing style

    # Plot ROC curve
    plt.plot(fpr, tpr, color=NVIDIA_GREEN, lw=3, label=f"ROC curve (AUROC = {roc_auc:.2f})")

    # Plot diagonal reference line for random guessing
    plt.plot([0, 1], [0, 1], color="gray", lw=2, linestyle="--")

    # Customize plot appearance
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate", color=FONT_COLOR, fontsize=12)
    plt.ylabel("True Positive Rate", color=FONT_COLOR, fontsize=12)
    plt.title(
        "Zeroshot ROC Curve\nEvaluating the discriminative performance of Evo 2 predictions",
        color=FONT_COLOR,
        fontsize=16,
        loc="left",
    )

    # Customize grid and tick colors
    plt.grid(color=GRID_COLOR, linestyle="--", linewidth=0.5)
    plt.tick_params(colors=FONT_COLOR)

    # Set background color
    plt.gca().set_facecolor(BACKGROUND_COLOR)

    # Add legend
    plt.legend(loc="lower right", frameon=True, facecolor=BACKGROUND_COLOR, edgecolor=GRID_COLOR)

# %%
plot_roc_curve(brca1_df)
# Out:
# 2025-11-05 00:31:39,376 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=16.0.
# 2025-11-05 00:31:39,377 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,378 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:39,378 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:39,379 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,380 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,380 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,381 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:39,382 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,382 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:39,383 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2025-11-05 00:31:39,383 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,384 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:39,384 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,385 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,386 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,386 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,387 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:39,387 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,388 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,389 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,389 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,390 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,391 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:39,391 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,392 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:39,393 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,393 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,394 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,395 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,395 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:39,395 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,395 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,396 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,396 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,397 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:39,398 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,398 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,399 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2025-11-05 00:31:39,400 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2025-11-05 00:31:39,400 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-11-05 00:31:39,401 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,401 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-11-05 00:31:39,402 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,403 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-11-05 00:31:39,403 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-11-05 00:31:39,404 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2025-11-05 00:31:39,405 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=16.0 to DejaVu Sans ('/usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %%
# Check if the AUC is a reasonable value for our CI suite when we run the full model
assert FAST_CI_MODE or auroc >= 0.73

# %% [markdown]
# ### Full Sample Performance
#
# The above analysis may have been performed on a subset of the available data.
#
# For comparison, the table below presents the AUROC scores for different model sizes trained on the *full dataset* (100% sample fraction).
#
# | Model Size  | Dataset Sample Fraction | AUROC |
# |------------|------------------------|-------|
# | Evo 2 1B   | 100%                   | 0.74  |
# | Evo 2 7B   | 100%                   | 0.87  |
